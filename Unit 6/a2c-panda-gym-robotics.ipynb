# %% [markdown]
# # Create a virtual display 🔽

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# # Install dependencies 🔽

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# !pip install huggingface_sb3
# !pip install huggingface_hub
# !pip install panda_gym
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.29.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Collecting shimmy~=1.1.0 (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.1.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (11.0.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 9.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2.4.1)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (6.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20->stable-baselines3[extra]) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.12.14)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.4 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446667 sha256=248f6d9005926d75c8a25dc55b1dd3d966767cd18f4e6258209cf86d392beb2f
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom, shimmy, ale-py
#   Attempting uninstall: shimmy
#     Found existing installation: Shimmy 1.3.0
#     Uninstalling Shimmy-1.3.0:
#       Successfully uninstalled Shimmy-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.16.10 requires shimmy>=1.2.1, but you have shimmy 1.1.0 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 shimmy-1.1.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.0->gymnasium) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.0->gymnasium) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->gymnasium) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.0->gymnasium) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.0->gymnasium) (2024.2.0)
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (0.27.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (6.0.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.12.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->huggingface_sb3) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->huggingface_sb3) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->huggingface_sb3) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->huggingface_sb3) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->huggingface_sb3) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2024.12.14)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->huggingface_sb3) (2024.2.0)
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Installing collected packages: huggingface_sb3
# Successfully installed huggingface_sb3-3.0
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.27.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.12.14)
# Collecting panda_gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: gymnasium>=0.26 in /usr/local/lib/python3.10/dist-packages (from panda_gym) (0.29.0)
# Collecting pybullet (from panda_gym)
#   Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from panda_gym) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from panda_gym) (1.13.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.26->panda_gym) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.26->panda_gym) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.26->panda_gym) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->panda_gym) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->panda_gym) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->panda_gym) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->panda_gym) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->panda_gym) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->panda_gym) (2024.2.0)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: pybullet, panda_gym
# Successfully installed panda_gym-3.0.7 pybullet-3.2.6

# %% [markdown]
# # Import the packages 📦

# %%
import os

import gymnasium as gym
import panda_gym

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import login
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow/lite/python/util.py:55: DeprecationWarning: jax.xla_computation is deprecated. Please use the AOT APIs; see https://jax.readthedocs.io/en/latest/aot.html. For example, replace xla_computation(f)(*xs) with jit(f).lower(*xs).compiler_ir('hlo'). See CHANGELOG.md for 0.4.30 for more examples.
#   from jax import xla_computation as _xla_computation

# %% [markdown]
# # PandaReachDense-v3 🦾
# The agent we’re going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the end-effector is the device at the end of a robotic arm designed to interact with the environment.
#
# In PandaReach, the robot must place its end-effector at a target position (green ball).
#
# We’re going to use the dense version of this environment. It means we’ll get a dense reward function that will provide a reward at each timestep (the closer the agent is to completing the task, the higher the reward). Contrary to a sparse reward function where the environment return a reward if and only if the task is completed.
#
# Also, we’re going to use the End-effector displacement control, it means the action corresponds to the displacement of the end-effector. We don’t control the individual motion of each joint (joint control).

# %% [markdown]
# ## The environment 🎮

# %%
env_id = "PandaReachDense-v3"

env = gym.make(env_id)

s_size = env.observation_space.shape
a_size = env.action_space
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation OrderedDict([('achieved_goal', array([8.114315 , 1.5747985, 5.0605803], dtype=float32)), ('desired_goal', array([-8.458551 , -9.493125 ,  3.1096568], dtype=float32)), ('observation', array([-6.698305 , -4.4603224, -4.3671637, -9.454221 ,  6.4856853,
#        -7.460611 ], dtype=float32))])
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The observation space is a dictionary with 3 different elements:
#
# - achieved_goal: (x,y,z) position of the goal.
# - desired_goal: (x,y,z) distance between the goal position and the current object position.
# - observation: position (x,y,z) and velocity of the end-effector (vx, vy, vz).

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box(-1.0, 1.0, (3,), float32)
# Action Space Sample [ 0.6445129   0.71101964 -0.51594174]

# %% [markdown]
# The action space is a vector with 3 values:
#
# - Control x, y, z movement

# %% [markdown]
# ## Normalize observation and rewards

# %%
env = make_vec_env(env_id, n_envs=4)

# Adding this wrapper to normalize the observation and the reward
env = VecNormalize(env, norm_obs=True, norm_reward=True)

# %% [markdown]
# # Create the A2C Model 🤖

# %%
model = A2C("MultiInputPolicy", env, device="cpu", verbose=1)
# Out:
# Using cpu device

# %%
model.learn(1_000_000)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | -12.7    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.814    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.918    |
# |    std                | 1.01     |
# |    value_loss         | 0.278    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43       |
# |    ep_rew_mean        | -11.9    |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 200      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -2.11    |
# |    std                | 1.02     |
# |    value_loss         | 0.378    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.9     |
# |    ep_rew_mean        | -11.7    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 300      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.584    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.48    |
# |    std                | 1.02     |
# |    value_loss         | 0.0689   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 42.9     |
# |    ep_rew_mean        | -11.3    |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 400      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.823   |
# |    std                | 1.02     |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43.8     |
# |    ep_rew_mean        | -11.1    |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 500      |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.115   |
# |    std                | 1.02     |
# |    value_loss         | 0.0227   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44.1     |
# |    ep_rew_mean        | -11      |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 600      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.34    |
# |    explained_variance | 0.883    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.178    |
# |    std                | 1.03     |
# |    value_loss         | 0.0954   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 45.1     |
# |    ep_rew_mean        | -10.6    |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 700      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.34    |
# |    explained_variance | 0.805    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00385  |
# |    std                | 1.03     |
# |    value_loss         | 0.066    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.6     |
# |    ep_rew_mean        | -8.4     |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 800      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.34    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.272    |
# |    std                | 1.03     |
# |    value_loss         | 0.0412   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.6     |
# |    ep_rew_mean        | -6.53    |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 900      |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.36    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0164  |
# |    std                | 1.03     |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.7     |
# |    ep_rew_mean        | -6.68    |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 1000     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.38    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.633   |
# |    std                | 1.04     |
# |    value_loss         | 0.0333   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 37.3     |
# |    ep_rew_mean        | -6.83    |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 1100     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.37    |
# |    explained_variance | 0.898    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.341    |
# |    std                | 1.04     |
# |    value_loss         | 0.0297   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 33.6     |
# |    ep_rew_mean        | -5.46    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 1200     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.37    |
# |    explained_variance | 0.292    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.348   |
# |    std                | 1.04     |
# |    value_loss         | 0.0331   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 22.4     |
# |    ep_rew_mean        | -3.03    |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 1300     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.37    |
# |    explained_variance | 0.0305   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.849    |
# |    std                | 1.04     |
# |    value_loss         | 0.418    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 12.8     |
# |    ep_rew_mean        | -1.43    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 1400     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | -7.65    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.86     |
# |    std                | 1.03     |
# |    value_loss         | 0.612    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.85     |
# |    ep_rew_mean        | -0.651   |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 1500     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | -0.285   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.206   |
# |    std                | 1.02     |
# |    value_loss         | 0.00917  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 6.41     |
# |    ep_rew_mean        | -0.575   |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 1600     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | -0.97    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.219   |
# |    std                | 1        |
# |    value_loss         | 0.0116   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.97     |
# |    ep_rew_mean        | -0.43    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 1700     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.22    |
# |    explained_variance | -0.495   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.186    |
# |    std                | 0.988    |
# |    value_loss         | 0.012    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.77     |
# |    ep_rew_mean        | -0.397   |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 1800     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | -0.83    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.00771 |
# |    std                | 0.974    |
# |    value_loss         | 0.00435  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 4.12     |
# |    ep_rew_mean        | -0.324   |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 1900     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.11    |
# |    explained_variance | -0.00751 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.0763   |
# |    std                | 0.953    |
# |    value_loss         | 0.00192  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.88     |
# |    ep_rew_mean        | -0.308   |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 2000     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.08    |
# |    explained_variance | 0.257    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0273  |
# |    std                | 0.942    |
# |    value_loss         | 0.00211  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.82     |
# |    ep_rew_mean        | -0.313   |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 2100     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.04    |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0887  |
# |    std                | 0.93     |
# |    value_loss         | 0.00784  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.6      |
# |    ep_rew_mean        | -0.3     |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 2200     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | 0.379    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0617  |
# |    std                | 0.918    |
# |    value_loss         | 0.00251  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.06     |
# |    ep_rew_mean        | -0.246   |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 2300     |
# |    time_elapsed       | 124      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -3.97    |
# |    explained_variance | 0.677    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0607  |
# |    std                | 0.909    |
# |    value_loss         | 0.000639 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.14     |
# |    ep_rew_mean        | -0.246   |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 2400     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -3.94    |
# |    explained_variance | -0.0944  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0247  |
# |    std                | 0.899    |
# |    value_loss         | 0.00135  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.21     |
# |    ep_rew_mean        | -0.26    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 2500     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -3.91    |
# |    explained_variance | 0.314    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0705  |
# |    std                | 0.89     |
# |    value_loss         | 0.00138  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.237   |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 2600     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 0.481    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.031   |
# |    std                | 0.885    |
# |    value_loss         | 0.0008   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.212   |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 2700     |
# |    time_elapsed       | 145      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -3.86    |
# |    explained_variance | 0.337    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0473  |
# |    std                | 0.876    |
# |    value_loss         | 0.000859 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.09     |
# |    ep_rew_mean        | -0.242   |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 2800     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -3.82    |
# |    explained_variance | 0.831    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.077   |
# |    std                | 0.863    |
# |    value_loss         | 0.000516 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.17     |
# |    ep_rew_mean        | -0.257   |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 2900     |
# |    time_elapsed       | 156      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -3.8     |
# |    explained_variance | 0.612    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.144    |
# |    std                | 0.86     |
# |    value_loss         | 0.00231  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.98     |
# |    ep_rew_mean        | -0.228   |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 3000     |
# |    time_elapsed       | 161      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -3.76    |
# |    explained_variance | 0.636    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0444  |
# |    std                | 0.847    |
# |    value_loss         | 0.000678 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.11     |
# |    ep_rew_mean        | -0.246   |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 3100     |
# |    time_elapsed       | 166      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -3.72    |
# |    explained_variance | -1.18    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.169    |
# |    std                | 0.836    |
# |    value_loss         | 0.0048   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.99     |
# |    ep_rew_mean        | -0.232   |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 3200     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -3.71    |
# |    explained_variance | 0.0731   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0652  |
# |    std                | 0.834    |
# |    value_loss         | 0.00173  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.227   |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 3300     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -3.7     |
# |    explained_variance | 0.71     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00191  |
# |    std                | 0.829    |
# |    value_loss         | 0.000281 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.226   |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 3400     |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -3.68    |
# |    explained_variance | 0.401    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.00922  |
# |    std                | 0.823    |
# |    value_loss         | 0.000914 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.234   |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 3500     |
# |    time_elapsed       | 186      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -3.65    |
# |    explained_variance | 0.814    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0671   |
# |    std                | 0.818    |
# |    value_loss         | 0.000694 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.206   |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 3600     |
# |    time_elapsed       | 192      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -3.65    |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.00245  |
# |    std                | 0.816    |
# |    value_loss         | 0.000304 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.232   |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 3700     |
# |    time_elapsed       | 197      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -3.63    |
# |    explained_variance | 0.96     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0126  |
# |    std                | 0.812    |
# |    value_loss         | 7.95e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -0.215   |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 3800     |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.61    |
# |    explained_variance | 0.769    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0217  |
# |    std                | 0.805    |
# |    value_loss         | 0.000537 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.97     |
# |    ep_rew_mean        | -0.232   |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 3900     |
# |    time_elapsed       | 207      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.58    |
# |    explained_variance | 0.327    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0546   |
# |    std                | 0.798    |
# |    value_loss         | 0.00121  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.87     |
# |    ep_rew_mean        | -0.225   |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4000     |
# |    time_elapsed       | 212      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.56    |
# |    explained_variance | 0.446    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0281   |
# |    std                | 0.792    |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.12     |
# |    ep_rew_mean        | -0.246   |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4100     |
# |    time_elapsed       | 217      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.51    |
# |    explained_variance | 0.738    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0237   |
# |    std                | 0.781    |
# |    value_loss         | 0.000452 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.209   |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4200     |
# |    time_elapsed       | 223      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.5     |
# |    explained_variance | 0.518    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0418  |
# |    std                | 0.777    |
# |    value_loss         | 0.000736 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.71     |
# |    ep_rew_mean        | -0.216   |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4300     |
# |    time_elapsed       | 228      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.47    |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0016   |
# |    std                | 0.77     |
# |    value_loss         | 0.000366 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76     |
# |    ep_rew_mean        | -0.211   |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4400     |
# |    time_elapsed       | 233      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.45    |
# |    explained_variance | 0.8      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0398   |
# |    std                | 0.764    |
# |    value_loss         | 0.000511 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.229   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4500     |
# |    time_elapsed       | 238      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.87     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0323  |
# |    std                | 0.759    |
# |    value_loss         | 0.000359 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.59     |
# |    ep_rew_mean        | -0.198   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4600     |
# |    time_elapsed       | 243      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.43    |
# |    explained_variance | 0.787    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.0284  |
# |    std                | 0.758    |
# |    value_loss         | 0.000318 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.23    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4700     |
# |    time_elapsed       | 249      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.4     |
# |    explained_variance | 0.699    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0163   |
# |    std                | 0.751    |
# |    value_loss         | 0.000452 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.223   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4800     |
# |    time_elapsed       | 254      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0444   |
# |    std                | 0.749    |
# |    value_loss         | 0.000453 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.237   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 4900     |
# |    time_elapsed       | 259      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | -0.451   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0374  |
# |    std                | 0.748    |
# |    value_loss         | 0.00149  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.225   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5000     |
# |    time_elapsed       | 264      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.398    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.189   |
# |    std                | 0.746    |
# |    value_loss         | 0.00452  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.94     |
# |    ep_rew_mean        | -0.235   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5100     |
# |    time_elapsed       | 269      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.915    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0618  |
# |    std                | 0.747    |
# |    value_loss         | 0.000558 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.218   |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5200     |
# |    time_elapsed       | 275      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0.477    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0747  |
# |    std                | 0.739    |
# |    value_loss         | 0.00274  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.215   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5300     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | 0.127    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0631  |
# |    std                | 0.737    |
# |    value_loss         | 0.00216  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.91     |
# |    ep_rew_mean        | -0.224   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5400     |
# |    time_elapsed       | 285      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.32    |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0717   |
# |    std                | 0.732    |
# |    value_loss         | 0.000854 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.237   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5500     |
# |    time_elapsed       | 290      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.32    |
# |    explained_variance | 0.868    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0229   |
# |    std                | 0.732    |
# |    value_loss         | 0.000187 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.212   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5600     |
# |    time_elapsed       | 296      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.29    |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00149 |
# |    std                | 0.725    |
# |    value_loss         | 0.000177 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.04     |
# |    ep_rew_mean        | -0.244   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5700     |
# |    time_elapsed       | 301      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3.27    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0246  |
# |    std                | 0.72     |
# |    value_loss         | 0.000376 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3        |
# |    ep_rew_mean        | -0.245   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5800     |
# |    time_elapsed       | 306      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.28    |
# |    explained_variance | 0.735    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0337   |
# |    std                | 0.722    |
# |    value_loss         | 0.000763 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.85     |
# |    ep_rew_mean        | -0.223   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5900     |
# |    time_elapsed       | 311      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -3.26    |
# |    explained_variance | 0.838    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0944   |
# |    std                | 0.717    |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.12     |
# |    ep_rew_mean        | -0.257   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6000     |
# |    time_elapsed       | 317      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -3.23    |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0323  |
# |    std                | 0.711    |
# |    value_loss         | 0.000226 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.9      |
# |    ep_rew_mean        | -0.23    |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6100     |
# |    time_elapsed       | 322      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -3.23    |
# |    explained_variance | 0.707    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.00332 |
# |    std                | 0.709    |
# |    value_loss         | 0.00075  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.93     |
# |    ep_rew_mean        | -0.237   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6200     |
# |    time_elapsed       | 327      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -3.21    |
# |    explained_variance | 0.704    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0089  |
# |    std                | 0.706    |
# |    value_loss         | 0.000761 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.72     |
# |    ep_rew_mean        | -0.21    |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6300     |
# |    time_elapsed       | 332      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -3.2     |
# |    explained_variance | 0.891    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.03     |
# |    std                | 0.702    |
# |    value_loss         | 0.000349 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.11     |
# |    ep_rew_mean        | -0.245   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6400     |
# |    time_elapsed       | 337      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -3.16    |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0788  |
# |    std                | 0.693    |
# |    value_loss         | 0.00149  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.222   |
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6500     |
# |    time_elapsed       | 343      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 0.00478  |
# |    std                | 0.69     |
# |    value_loss         | 9.93e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 3.08     |
# |    ep_rew_mean        | -0.246   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6600     |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.798    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0424  |
# |    std                | 0.688    |
# |    value_loss         | 0.000788 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.82     |
# |    ep_rew_mean        | -0.217   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6700     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -3.12    |
# |    explained_variance | 0.533    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0498  |
# |    std                | 0.684    |
# |    value_loss         | 0.0015   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.96     |
# |    ep_rew_mean        | -0.229   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6800     |
# |    time_elapsed       | 358      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -3.1     |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00844 |
# |    std                | 0.68     |
# |    value_loss         | 0.000191 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.211   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6900     |
# |    time_elapsed       | 363      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | 0.913    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.0163  |
# |    std                | 0.675    |
# |    value_loss         | 0.00021  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.89     |
# |    ep_rew_mean        | -0.238   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 7000     |
# |    time_elapsed       | 369      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.000591 |
# |    std                | 0.675    |
# |    value_loss         | 0.000141 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.95     |
# |    ep_rew_mean        | -0.237   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 7100     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -3.07    |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.0162   |
# |    std                | 0.675    |
# |    value_loss         | 0.00045  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.214   |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 7200     |
# |    time_elapsed       | 379      |
# |    total_timesteps    | 144000   |
# ...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.6      |
# |    ep_rew_mean        | -0.197   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 47700    |
# |    time_elapsed       | 2487     |
# |    total_timesteps    | 954000   |
# | train/                |          |
# |    entropy_loss       | 0.501    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47699    |
# |    policy_loss        | 0.00171  |
# |    std                | 0.209    |
# |    value_loss         | 0.000558 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.201   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 47800    |
# |    time_elapsed       | 2492     |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | 0.508    |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | -0.00531 |
# |    std                | 0.208    |
# |    value_loss         | 0.000391 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.84     |
# |    ep_rew_mean        | -0.218   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 47900    |
# |    time_elapsed       | 2497     |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | 0.496    |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.00122  |
# |    std                | 0.21     |
# |    value_loss         | 0.000272 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.67     |
# |    ep_rew_mean        | -0.211   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48000    |
# |    time_elapsed       | 2502     |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | 0.482    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | 0.00518  |
# |    std                | 0.21     |
# |    value_loss         | 0.000682 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.67     |
# |    ep_rew_mean        | -0.208   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48100    |
# |    time_elapsed       | 2508     |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | 0.478    |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 0.00608  |
# |    std                | 0.211    |
# |    value_loss         | 0.00239  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.71     |
# |    ep_rew_mean        | -0.208   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48200    |
# |    time_elapsed       | 2513     |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | 0.476    |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | 0.00285  |
# |    std                | 0.211    |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.222   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48300    |
# |    time_elapsed       | 2518     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | 0.477    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | 0.00132  |
# |    std                | 0.211    |
# |    value_loss         | 0.000305 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.204   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48400    |
# |    time_elapsed       | 2523     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | 0.485    |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | -0.00294 |
# |    std                | 0.21     |
# |    value_loss         | 0.00101  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.212   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48500    |
# |    time_elapsed       | 2529     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | 0.471    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | 0.000389 |
# |    std                | 0.211    |
# |    value_loss         | 7.6e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.81     |
# |    ep_rew_mean        | -0.228   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48600    |
# |    time_elapsed       | 2534     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | 0.479    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | 0.0124   |
# |    std                | 0.211    |
# |    value_loss         | 0.000303 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.56     |
# |    ep_rew_mean        | -0.192   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48700    |
# |    time_elapsed       | 2539     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | 0.492    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | 0.00392  |
# |    std                | 0.21     |
# |    value_loss         | 0.000214 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.64     |
# |    ep_rew_mean        | -0.203   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48800    |
# |    time_elapsed       | 2544     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | 0.481    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | -0.0101  |
# |    std                | 0.211    |
# |    value_loss         | 0.000323 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.213   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 48900    |
# |    time_elapsed       | 2550     |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | 0.494    |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | 0.00354  |
# |    std                | 0.21     |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.79     |
# |    ep_rew_mean        | -0.221   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49000    |
# |    time_elapsed       | 2555     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | 0.501    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | -0.00419 |
# |    std                | 0.21     |
# |    value_loss         | 0.000273 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.77     |
# |    ep_rew_mean        | -0.214   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49100    |
# |    time_elapsed       | 2560     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | 0.49     |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | 0.00728  |
# |    std                | 0.211    |
# |    value_loss         | 0.000352 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.78     |
# |    ep_rew_mean        | -0.218   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49200    |
# |    time_elapsed       | 2566     |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | 0.483    |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -0.00153 |
# |    std                | 0.212    |
# |    value_loss         | 0.000789 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.86     |
# |    ep_rew_mean        | -0.23    |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49300    |
# |    time_elapsed       | 2571     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | 0.463    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | 0.00572  |
# |    std                | 0.213    |
# |    value_loss         | 0.000389 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.7      |
# |    ep_rew_mean        | -0.208   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49400    |
# |    time_elapsed       | 2576     |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | 0.467    |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | -0.00481 |
# |    std                | 0.213    |
# |    value_loss         | 0.000428 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.75     |
# |    ep_rew_mean        | -0.218   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49500    |
# |    time_elapsed       | 2581     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | 0.481    |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | 0.00642  |
# |    std                | 0.212    |
# |    value_loss         | 0.000921 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.218   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49600    |
# |    time_elapsed       | 2587     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | 0.491    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.0139  |
# |    std                | 0.212    |
# |    value_loss         | 0.00117  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.57     |
# |    ep_rew_mean        | -0.195   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49700    |
# |    time_elapsed       | 2592     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | 0.498    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | 0.0055   |
# |    std                | 0.211    |
# |    value_loss         | 0.000193 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.75     |
# |    ep_rew_mean        | -0.212   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49800    |
# |    time_elapsed       | 2597     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | 0.512    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | 0.0012   |
# |    std                | 0.21     |
# |    value_loss         | 0.000395 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.73     |
# |    ep_rew_mean        | -0.206   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 49900    |
# |    time_elapsed       | 2602     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | 0.523    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | 0.00797  |
# |    std                | 0.209    |
# |    value_loss         | 0.000341 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.8      |
# |    ep_rew_mean        | -0.214   |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 50000    |
# |    time_elapsed       | 2608     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | 0.532    |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | 0.0011   |
# |    std                | 0.209    |
# |    value_loss         | 0.000473 |
# ------------------------------------

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-PandaReachDense-v3")
env.save("vec_normalize.pkl")

# %% [markdown]
# # Evaluate the agent 📈

# %%
eval_env = DummyVecEnv([lambda: gym.make(env_id)])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

eval_env.render_mode = "rgb_array"
# do not update at test time
eval_env.training = False
# no need to normalize reward at test time
eval_env.norm_reward = False

model = A2C.load("a2c-PandaReachDense-v3")
mean_reward, std_reward = evaluate_policy(model, eval_env)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: -0.25 +/- 0.12
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/save_util.py:437: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# # Publish your trained model on the Hub 🔥

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_sb3 import package_to_hub

package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"wowthecoder/a2c-{env_id}", 
    commit_message="Initial commit",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmpd9ly021e/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.10/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /tmp/tmpd9ly021e/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpd9ly021e/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpd9ly021e/-step-0-to-step-1000.mp4
# ℹ Pushing repo wowthecoder/a2c-PandaReachDense-v3 to the Hugging Face
# Hub
# policy.optimizer.pth:   0%|          | 0.00/48.2k [00:00<?, ?B/s]
# a2c-PandaReachDense-v3.zip:   0%|          | 0.00/111k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# policy.pth:   0%|          | 0.00/46.3k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.62k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/wowthecoder/a2c-PandaReachDense-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/wowthecoder/a2c-PandaReachDense-v3/commit/02bec1dc136955edadacbdff33f6faba2944fc39', commit_message='Initial commit', commit_description='', oid='02bec1dc136955edadacbdff33f6faba2944fc39', pr_url=None, repo_url=RepoUrl('https://huggingface.co/wowthecoder/a2c-PandaReachDense-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='wowthecoder/a2c-PandaReachDense-v3'), pr_revision=None, pr_num=None)
